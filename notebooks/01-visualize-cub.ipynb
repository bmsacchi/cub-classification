# %%
import pandas as pd

# %%
df = pd.read_csv('../data/processed/CUB_200_2011/train.csv')

# %%
df
# Out:
#                                                filename  class_id  \
# 0     001.Black_footed_Albatross/Black_Footed_Albatr...         1
# 1     001.Black_footed_Albatross/Black_Footed_Albatr...         1
# 2     001.Black_footed_Albatross/Black_Footed_Albatr...         1
# 3     001.Black_footed_Albatross/Black_Footed_Albatr...         1
# 4     001.Black_footed_Albatross/Black_Footed_Albatr...         1
# ...                                                 ...       ...
# 5989  200.Common_Yellowthroat/Common_Yellowthroat_00...       200
# 5990  200.Common_Yellowthroat/Common_Yellowthroat_00...       200
# 5991  200.Common_Yellowthroat/Common_Yellowthroat_00...       200
# 5992  200.Common_Yellowthroat/Common_Yellowthroat_00...       200
# 5993  200.Common_Yellowthroat/Common_Yellowthroat_00...       200
#
#                       class_name  x_min  y_min   x_max   y_max
# 0     001.Black_footed_Albatross  62.27  20.00  130.82  196.00
# ...

# %%
relative_path = lambda x: "../data/processed/CUB_200_2011/images/" + x

# %%
# Visualize four random images
import matplotlib.pyplot as plt

#sample = df.sample(4)
# filter images that contain the word "warbler" in the filename - for fun!
sample = df[df['filename'].str.contains('Warbler')].sample(4)

fig, axes = plt.subplots(1, 4, figsize=(12, 3))
for ax, (_, row) in zip(axes, sample.iterrows()):
    ax.imshow(plt.imread(relative_path(row['filename'])))

    # Draw bounding box
    x_min, y_min, x_max, y_max = row['x_min'], row['y_min'], row['x_max'], row['y_max']
    ax.add_patch(plt.Rectangle((x_min, y_min), x_max - x_min, y_max - y_min,
                                 fill=False, edgecolor='red', linewidth=2))
    ax.set_xlabel(f"{row['x_min']}, {row['y_min']}, {row['x_max']}, {row['y_max']}")
    ax.set_xticks([])
    ax.set_yticks([])

    ax.set_title(row['class_name'])
    ax.axis('off')
plt.tight_layout()
